# %%
#
# This is a working 'notebook' of investigations and analysis for the WISE LC QSOs.
#

# %%
from astropy.io import fits

# %%
data_path = 'data/dr3_wise_lc_sample.fits'

data_full = fits.open(data_path)
tbdata = data_full[1].data # assuming the first extension is a table

# %%
tbdata
# Out:
# FITS_rec([ (  38.86555481,   22.86569786,  0.99948949, 4, 0, 0, 1, 1,    72.07797241,    94.73147583,   1.70704712e+02,   8.87312775e+01,   5.69015694e+01,   2.95770931e+01,   56.87229919,    86.10326385,   69.12316895,   114.47808075,  0.45029703,  0.54774678, [1, 1, 1, 1, 0], 0, 1, 0, 1, '0030p030',  1923.45349121,  1648.51184082),
#        (  54.69508743,   30.75159836,  0.98584288, 4, 0, 0, 1, 1,    95.35372162,   127.09151459,   2.04320877e+02,   1.03792091e+02,   6.81069565e+01,   3.45973625e+01,   77.96305847,   108.23860931,   93.45011139,   148.87483215,  0.35623336,  0.50560367, [1, 1, 1, 1, 0], 0, 1, 0, 1, '0032p227',  1667.26660156,  1746.52124023),
# ...

# %%
data_full.info()
# Out:
# Filename: data/dr3_wise_lc_sample.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU       4   ()
#   1              BinTableHDU     73   248R x 28C   ['E', 'E', 'E', 'J', 'J', 'J', 'B', 'B', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', '5B', 'B', 'B', 'B', 'B', '8A', 'E', 'E']
#   2              BinTableHDU    167   248R x 69C   [J, 8A, J, L, J, I, L, 4A, D, E, D, E, E, E, E, E, L, L, 5E, E, E, E, I, I, J, I, J, 6E, 6E, 48E, 48E, 48E, 6E, 6B, 6E, 6E, 6E, 6E, 6I, 6I, 6E, 4E, 4E, 4E, 4I, 4E, 4E, 10E, 10E, 10I, 10E, 10E, 10E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 6E, 6E]
#   3              BinTableHDU     45   248R x 14C   [18A, D, D, D, J, J, J, E, E, E, E, E, I, I]
